# %% [markdown]
# # notes

# %%
"""
it's not all done yet but the goal is to input a dataset and output the following:
# patients
# trees
# trees for each patient
average # trees per patient
average branches per tree
average depth (both nodal depth and alterational depth) per tree
average alterations per tree
average nodes per tree
# genes
# alterations
(alteration, frequency) pairs
for each alteration, its frequency of being at each depth
average # clusters per tree
average alterations in a cluster
and possibly other things
"""

# %% [markdown]
# # imports

# %%
import sys
sys.path.append("code")
import final_functions as ff

# %%
import importlib
importlib.reload(ff)
pass

# %% [markdown]
# # AML

# %%
ff.show_summary("AML")
# Out:
# dataset: AML
# there are 120 patients
# there are 120 trees
# the median number of trees per patient is 1.0
# there are 30 unique alterations
# alterations: ['GATA2', 'ASXL1', 'IDH2', 'RUNX1', 'NPM1', 'KRAS', 'ETV6', 'WT1', 'MYC', 'U2AF1', 'SETBP1', 'SRSF2', 'EZH2', 'NRAS', 'FLT3', 'KIT', 'BCOR', 'CBL', 'PTPN11', 'TET2', 'CSF3R', 'STAG2', 'IDH1', 'JAK2', 'SMC3', 'PPM1D', 'TP53', 'PHF6', 'DNMT3A', 'SF3B1']
# there are 496 ancestral relationships
# there are 118 incomparable relationships
# there are 6 clustered relationships
# alteration frequency: [('NPM1', 49), ('FLT3', 47), ('NRAS', 43), ('DNMT3A', 39), ('IDH2', 31), ('SRSF2', 25), ('RUNX1', 24), ('KRAS', 19), ('WT1', 18), ('PTPN11', 18), ('TET2', 15), ('ASXL1', 15), ('IDH1', 14), ('TP53', 13), ('SF3B1', 11), ('U2AF1', 7), ('GATA2', 5), ('KIT', 4), ('EZH2', 4), ('JAK2', 3), ('SETBP1', 3), ('PPM1D', 3), ('STAG2', 2), ('PHF6', 2), ('MYC', 2), ('BCOR', 2), ('SMC3', 1), ('ETV6', 1), ('CBL', 1), ('CSF3R', 1)]

# %% [markdown]
# # NSCLC

# %%
ff.show_summary("NSCLC")
# Out:
# dataset: NSCLC
# there are 89 patients
# there are 89 trees
# the median number of trees per patient is 1.0
# there are 87 unique alterations
# alterations: ['CIC', 'DNM2', 'PRF1', 'GATA3', 'NCOA6amp', 'MAP3K1', 'WT1', 'NCOR1', 'KEAP1', 'COL5A2amp', 'FANCM', 'KRASamp', 'CMTR2', 'MET', 'BRAF', 'FAT1', 'RNF43', 'CCND1amp', 'SMAD4', 'UBR5', 'SERPINB13', 'PASK', 'MGA', 'CDKN2A', 'SPEN', 'PLXNB2', 'COL2A1', 'PHOX2B', 'WRN', 'SMARCA4', 'FANCC', 'ARID2', 'TERTamp', 'U2AF1', 'SETD2', 'KMT2D', 'APC', 'TSC2', 'NFE2L2', 'PTPRC', 'PDGFRAamp', 'FGFR1amp', 'NF1', 'EGFRamp', 'SGK223', 'ASXL1', 'CREBBP', 'LATS1', 'ARID1B', 'KRAS', 'NOTCH1', 'BAP1', 'PIK3CAamp', 'RB1', 'ARHGAP35', 'NOTCH2', 'RASA1', 'FBXW7', 'STK11', 'PTEN', 'TP53', 'CTNNB1', 'FAS', 'NCOA6', 'EGFR', 'POLE', 'SGK223amp', 'MLH1', 'PRDM1', 'CUX1', 'METamp', 'CBLB', 'ATM', 'EP300', 'NRAS', 'FLT4', 'NFE2L2amp', 'MYCamp', 'PIK3CA', 'DICER1', 'RAD21', 'IKZF1', 'CHEK2', 'CYLD', 'SOX2amp', 'KMT2C', 'COL5A2']
# ...

# %% [markdown]
# # TRACERx

# %%
ff.show_summary("TRACERx")
# Out:
# dataset: TRACERx
# there are 99 patients
# there are 137 trees
# the median number of trees per patient is 1.0
# there are 79 unique alterations
# alterations: ['PASK', 'MGA', 'ARHGAP35', 'TP53', 'WRN', 'EGFR', 'NF1', 'EP300', 'TERT', 'RB1', 'IKZF1', 'MET', 'KRAS', 'CTNNB1', 'PIK3CA', 'CDKN2A', 'NOTCH1', 'SMAD4', 'NRAS', 'CMTR2', 'BRAF', 'KEAP1', 'PLXNB2', 'FANCC', 'MAP3K1', 'SGK223', 'STK11', 'ARID2', 'MYC', 'U2AF1', 'PRDM1', 'NFE2L2', 'KMT2C', 'SETD2', 'FLT4', 'RNF43', 'BAP1', 'ASXL1', 'FAT1', 'DNM2', 'LATS1', 'PTPRC', 'ARID1B', 'SPEN', 'CBLB', 'COL5A2', 'COL2A1', 'NCOR1', 'PRF1', 'CHEK2', 'CIC', 'KMT2D', 'POLE', 'ATM', 'SERPINB13', 'APC', 'CCND1', 'TSC2', 'FBXW7', 'FGFR1', 'RAD21', 'FAS', 'CREBBP', 'NCOA6', 'PHOX2B', 'GATA3', 'NOTCH2', 'UBR5', 'FANCM', 'RASA1', 'SMARCA4', 'SOX2', 'CYLD', 'MLH1', 'PDGFRA', 'PTEN', 'DICER1', 'WT1', 'CUX1']
# ...
